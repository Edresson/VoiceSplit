# %% [markdown]
# This is a noteboook used to generate the speaker embeddings with the  GE2E model.

# %%
import sys 
sys.path.insert(0, "../")

# %%
from utils.audio_processor import WrapperAudioProcessor as AudioProcessor 
from utils.generic_utils import load_config
import librosa
import os
import numpy as np
import torch
from glob import glob
from tqdm import tqdm
# Out:
# /home/charmander/Edresson/anaconda3/envs/voicesplit/lib/python3.6/site-packages/librosa/util/decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit

# %%
#Download encoder Checkpoint
#!wget https://github.com/Edresson/GE2E-Speaker-Encoder/releases/download/checkpoints/checkpoint-voicefilter-seungwonpark.pt -O embedder.pt

# %%
# speaker_encoder parameters 
num_mels = 40
n_fft = 512
emb_dim = 256
lstm_hidden = 768
lstm_layers = 3
window = 80
stride = 40

checkpoint_dir = "embedder.pt"

# %%
import torch
import torch.nn as nn

class LinearNorm(nn.Module):
    def __init__(self, lstm_hidden, emb_dim):
        super(LinearNorm, self).__init__()
        self.linear_layer = nn.Linear(lstm_hidden, emb_dim)

    def forward(self, x):
        return self.linear_layer(x)


class SpeakerEncoder(nn.Module):
    def __init__(self, num_mels, lstm_layers, lstm_hidden, window, stride):
        super(SpeakerEncoder, self).__init__()
        self.lstm = nn.LSTM(num_mels, lstm_hidden,
                            num_layers=lstm_layers,
                            batch_first=True)
        self.proj = LinearNorm(lstm_hidden, emb_dim)
        self.num_mels = num_mels
        self.lstm_layers = lstm_layers
        self.lstm_hidden = lstm_hidden
        self.window = window
        self.stride = stride

    def forward(self, mel):
        # (num_mels, T)
        mels = mel.unfold(1, self.window, self.stride) # (num_mels, T', window)
        mels = mels.permute(1, 2, 0) # (T', window, num_mels)
        x, _ = self.lstm(mels) # (T', window, lstm_hidden)
        x = x[:, -1, :] # (T', lstm_hidden), use last frame only
        x = self.proj(x) # (T', emb_dim)
        x = x / torch.norm(x, p=2, dim=1, keepdim=True) # (T', emb_dim)
        x = x.sum(0) / x.size(0) # (emb_dim), average pooling over time frames
        return x

# %%
embedder = SpeakerEncoder(num_mels, lstm_layers, lstm_hidden, window, stride).cuda()
chkpt_embed = torch.load(checkpoint_dir)
embedder.load_state_dict(chkpt_embed)
embedder.eval()
# Out:
# SpeakerEncoder(
#   (lstm): LSTM(40, 768, num_layers=3, batch_first=True)
#   (proj): LinearNorm(
#     (linear_layer): Linear(in_features=768, out_features=256, bias=True)
#   )
# )

# %%
# Set constants
DATA_ROOT_PATH = '../../../LibriSpeech/voicefilter-open-fiel-ao-paper-data/'
TRAIN_DATA = os.path.join(DATA_ROOT_PATH, 'train')
TEST_DATA = os.path.join(DATA_ROOT_PATH, 'test')
glob_re_wav_emb = '*-ref_emb.wav'
glob_re_emb = '*-emb.pt'

# %%
# load ap compativel with speaker encoder
config = {"backend":"voicefilter", "mel_spec": False,  "audio_len": 3, 
          "voicefilter":{"n_fft": 1200,"num_mels":40,"num_freq": 601,"sample_rate": 16000,"hop_length": 160,
                         "win_length": 400,"min_level_db": -100.0, "ref_level_db": 20.0, "preemphasis": 0.97,
                         "power": 1.5, "griffin_lim_iters": 60}}
ap = AudioProcessor(config)

# %%
os.listdir(TEST_DATA)
# Out:
# ['005549-target.wav',
#  '004185-target.pt',
#  '000492-ref_emb.wav',
#  '004125-mixed.wav',
#  '001272-mixed.wav',
#  '004410-ref_emb.wav',
#  '004563-target.pt',
#  '005316-target.pt',
#  '002196-mixed.pt',
#  '005060-target.wav',
#  '001233-target.wav',
#  '005520-mixed.pt',
#  '002855-mixed.pt',
#  '005006-mixed.pt',
#  '001233-target.pt',
#  '005390-mixed.wav',
#  '002673-target.pt',
#  '004728-ref_emb.wav',
#  '004270-mixed.wav',
#  '002485-mixed.wav',
#  '003695-mixed.wav',
#  '002860-ref_emb.wav',
#  '003389-mixed.pt',
#  '000135-target.pt',
#  '002448-target.wav',
#  '000128-ref_emb.wav',
#  '000328-target.pt',
#  '002688-target.pt',
#  '001498-target.wav',
#  '004841-target.wav',
#  '001116-target.wav',
#  '002646-target.wav',
#  '002876-mixed.wav',
#  '001722-ref_emb.wav',
#  '002453-ref_emb.wav',
#  '000378-ref_emb.wav',
#  '004537-ref_emb.wav',
#  '000542-mixed.pt',
#  '001553-mixed.pt',
#  '004414-mixed.pt',
#  '002534-mixed.pt',
#  '001932-mixed.pt',
#  '002633-target.pt',
#  '003422-ref_emb.wav',
#  '001864-target.pt',
#  '000666-ref_emb.wav',
#  '001519-mixed.wav',
#  '002715-mixed.pt',
#  '003959-target.pt',
#  '001218-target.pt',
#  '004817-ref_emb.wav',
#  '001935-mixed.pt',
#  '004283-target.wav',
#  '002702-target.pt',
#  '005452-target.pt',
#  '004092-mixed.pt',
#  '001895-target.wav',
#  '000958-target.wav',
#  '005544-target.pt',
#  '000408-ref_emb.wav',
#  '005562-target.wav',
#  '002296-mixed.wav',
#  '004113-target.wav',
#  '000072-target.pt',
#  '003930-target.wav',
#  '000876-mixed.wav',
#  '000265-target.pt',
#  '004463-mixed.wav',
#  '003597-mixed.pt',
#  '000092-mixed.wav',
#  '005420-target.wav',
#  '002322-target.pt',
#  '000691-ref_emb.wav',
#  '000118-target.pt',
#  '005474-mixed.pt',
#  '002749-ref_emb.wav',
#  '001231-ref_emb.wav',
#  '005289-ref_emb.wav',
#  '000324-ref_emb.wav',
#  '001426-ref_emb.wav',
#  '000651-target.wav',
#  '001776-target.wav',
#  '004384-target.wav',
#  '003519-mixed.pt',
#  '000597-mixed.pt',
#  '002186-ref_emb.wav',
#  '002496-target.pt',
#  '001658-ref_emb.wav',
#  '003294-target.wav',
#  '005069-mixed.pt',
#  '003684-target.wav',
#  '002112-ref_emb.wav',
#  '002877-target.wav',
#  '004101-target.wav',
#  '002501-target.pt',
#  '005212-target.wav',
#  '000251-target.pt',
#  '002680-mixed.wav',
#  '004809-target.pt',
#  '004691-target.wav',
#  '002882-mixed.wav',
#  '003946-mixed.pt',
#  '002850-mixed.wav',
#  '001542-mixed.pt',
#  '000868-mixed.pt',
#  '003279-ref_emb.wav',
#  '001687-mixed.pt',
#  '003099-mixed.pt',
#  '000857-target.wav',
#  '003246-ref_emb.wav',
#  '005432-mixed.pt',
#  '004091-mixed.wav',
#  '005300-mixed.wav',
#  '000760-ref_emb.wav',
#  '000694-ref_emb.wav',
#  '005417-mixed.wav',
#  '004173-mixed.pt',
#  '000709-ref_emb.wav',
#  '003825-target.wav',
#  '005458-mixed.pt',
#  '000592-target.pt',
#  '004479-ref_emb.wav',
#  '003443-mixed.wav',
#  '000087-target.wav',
#  '001749-mixed.pt',
#  '005203-mixed.pt',
#  '004910-target.wav',
#  '004238-mixed.pt',
#  '001339-target.pt',
#  '004296-mixed.wav',
#  '002582-mixed.pt',
#  '001257-ref_emb.wav',
#  '001527-ref_emb.wav',
#  '002782-target.wav',
#  '004239-mixed.pt',
#  '004424-target.wav',
#  '005322-mixed.wav',
#  '002391-target.pt',
#  '005075-target.wav',
#  '002900-target.pt',
#  '001878-ref_emb.wav',
#  '004356-mixed.pt',
#  '003970-mixed.wav',
#  '000282-mixed.wav',
#  '000063-target.wav',
#  '001557-ref_emb.wav',
#  '004962-ref_emb.wav',
#  '004324-mixed.wav',
#  '001162-mixed.pt',
#  '003489-target.wav',
#  '003327-target.pt',
#  '005351-mixed.wav',
#  '001830-target.pt',
#  '001456-target.wav',
#  '003072-mixed.wav',
#  '004032-mixed.pt',
#  '004032-ref_emb.wav',
#  '001979-mixed.wav',
#  '003471-mixed.wav',
#  '000513-mixed.wav',
#  '002377-ref_emb.wav',
#  '005494-target.pt',
#  '002933-target.pt',
#  '002850-target.wav',
#  '002548-mixed.pt',
#  '002276-target.pt',
#  '001183-ref_emb.wav',
#  '000420-target.pt',
#  '001378-target.wav',
#  '002721-target.wav',
#  '005434-mixed.pt',
#  '002200-mixed.wav',
#  '005050-mixed.pt',
#  '002251-target.wav',
#  '001161-mixed.pt',
#  '000305-target.pt',
#  '004785-target.pt',
#  '005502-target.wav',
#  '003647-target.wav',
#  '003094-target.wav',
#  '000385-target.wav',
#  '002377-target.pt',
#  '000119-mixed.wav',
#  '000497-mixed.pt',
#  '002976-target.pt',
#  '004776-ref_emb.wav',
#  '005559-target.pt',
#  '003870-mixed.pt',
#  '002494-target.wav',
#  '000001-mixed.pt',
#  '002194-target.pt',
#  '002465-mixed.pt',
#  '002391-mixed.pt',
#  '000174-mixed.pt',
#  '005323-ref_emb.wav',
#  '001068-mixed.wav',
#  '005326-target.pt',
#  '002780-mixed.wav',
#  '001755-ref_emb.wav',
#  '002983-ref_emb.wav',
#  '000466-mixed.pt',
#  '004827-target.pt',
#  '004288-mixed.pt',
#  '002647-target.pt',
#  '005344-mixed.pt',
#  '004304-target.wav',
#  '000934-mixed.pt',
#  '004120-ref_emb.wav',
#  '000947-ref_emb.wav',
#  '005335-mixed.wav',
#  '003416-mixed.wav',
#  '001243-mixed.pt',
#  '003204-ref_emb.wav',
#  '004295-mixed.pt',
#  '003785-target.pt',
#  '000910-mixed.pt',
#  '002908-target.pt',
#  '000896-mixed.wav',
#  '004493-ref_emb.wav',
#  '003363-target.pt',
#  '001400-target.wav',
#  '005305-target.pt',
#  '005282-ref_emb.wav',
#  '003424-target.pt',
#  '001456-mixed.wav',
#  '003719-target.wav',
#  '001230-target.wav',
#  '001372-ref_emb.wav',
#  '004382-ref_emb.wav',
#  '005230-target.wav',
#  '000176-ref_emb.wav',
#  '001208-mixed.pt',
#  '003301-ref_emb.wav',
#  '002960-ref_emb.wav',
#  '005156-ref_emb.wav',
#  '002591-ref_emb.wav',
#  '001679-target.wav',
#  '003181-target.pt',
#  '002469-mixed.wav',
#  '002063-mixed.pt',
#  '003070-mixed.wav',
#  '000335-target.wav',
#  '005385-mixed.wav',
#  '004379-mixed.pt',
#  '004012-ref_emb.wav',
#  '005334-mixed.wav',
#  '001428-mixed.pt',
#  '003984-mixed.wav',
#  '004904-target.pt',
#  '002222-target.pt',
#  '002569-target.wav',
#  '002153-ref_emb.wav',
#  '003756-target.wav',
#  '002955-mixed.pt',
#  '000446-mixed.pt',
#  '000855-mixed.wav',
#  '003478-mixed.pt',
#  '004530-mixed.wav',
#  '003719-mixed.pt',
#  '001315-target.pt',
#  '002682-target.wav',
#  '003929-target.wav',
#  '003137-mixed.wav',
#  '001246-mixed.pt',
#  '003955-target.pt',
#  '004495-mixed.wav',
#  '003095-target.wav',
#  '001367-mixed.pt',
#  '000589-target.wav',
#  '004921-mixed.pt',
#  '003033-ref_emb.wav',
#  '004344-mixed.pt',
#  '004342-mixed.pt',
#  '005137-mixed.pt',
#  '004453-mixed.pt',
#  '005034-mixed.pt',
#  '002594-mixed.pt',
#  '002271-target.wav',
#  '001585-target.wav',
#  '004320-mixed.wav',
#  '001746-target.wav',
#  '003968-mixed.pt',
#  '002781-mixed.pt',
#  '003056-mixed.wav',
#  '005401-mixed.wav',
#  '000513-mixed.pt',
#  '001980-target.pt',
#  '000693-target.wav',
#  '000644-ref_emb.wav',
#  '002251-ref_emb.wav',
#  '001722-mixed.pt',
#  '005419-target.pt',
#  '001870-target.wav',
#  '000313-target.pt',
#  '001830-ref_emb.wav',
#  '004827-target.wav',
#  '004958-target.pt',
#  '003861-mixed.pt',
#  '003803-ref_emb.wav',
#  '005431-target.wav',
#  '002078-mixed.pt',
#  '000677-mixed.pt',
#  '000627-ref_emb.wav',
#  '004410-target.pt',
#  '000064-mixed.wav',
#  '000711-target.pt',
#  '001760-mixed.pt',
#  '002838-target.pt',
#  '001849-target.wav',
#  '003969-ref_emb.wav',
#  '003838-ref_emb.wav',
#  '001842-target.pt',
#  '004611-mixed.wav',
#  '000445-target.wav',
#  '002280-target.wav',
#  '005252-target.wav',
#  '003500-target.pt',
#  '001406-mixed.wav',
#  '005464-mixed.wav',
#  '001111-mixed.pt',
#  '000644-mixed.wav',
#  '003071-target.wav',
#  '004807-ref_emb.wav',
#  '004932-target.pt',
#  '000744-target.pt',
#  '000367-mixed.wav',
#  '000000-mixed.wav',
#  '002094-ref_emb.wav',
#  '002715-target.pt',
#  '001991-ref_emb.wav',
#  '005329-ref_emb.wav',
#  '002037-mixed.pt',
#  '001008-target.pt',
#  '000519-mixed.pt',
#  '002614-target.pt',
#  '000683-target.pt',
#  '004140-ref_emb.wav',
#  '002477-mixed.wav',
#  '004376-target.wav',
#  '004095-ref_emb.wav',
#  '001755-mixed.wav',
#  '002802-ref_emb.wav',
#  '002322-ref_emb.wav',
#  '002337-target.wav',
#  '004174-ref_emb.wav',
#  '004146-mixed.pt',
#  '002578-ref_emb.wav',
#  '003842-ref_emb.wav',
#  '005164-target.wav',
#  '001486-target.wav',
#  '002459-target.pt',
#  '001536-mixed.wav',
#  '004946-mixed.wav',
#  '001992-mixed.pt',
#  '002103-mixed.wav',
#  '000738-ref_emb.wav',
#  '001013-mixed.wav',
#  '002293-target.pt',
#  '001411-mixed.wav',
#  '000478-mixed.pt',
#  '005329-target.wav',
#  '001139-target.wav',
#  '000425-ref_emb.wav',
#  '002159-target.pt',
#  '001285-mixed.pt',
#  '000975-target.wav',
#  '002512-mixed.pt',
#  '000882-ref_emb.wav',
#  '004163-target.wav',
#  '005474-ref_emb.wav',
#  '004275-target.pt',
#  '001404-target.wav',
#  '002017-target.pt',
#  '001428-ref_emb.wav',
#  '005477-ref_emb.wav',
#  '004629-target.pt',
#  '003372-target.wav',
#  '002181-target.pt',
#  '001498-mixed.pt',
#  '003246-mixed.pt',
#  '004772-mixed.wav',
#  '002281-mixed.wav',
#  '001396-mixed.pt',
#  '002867-target.wav',
#  '001064-target.pt',
#  '005464-target.pt',
#  '001979-target.pt',
#  '004024-target.wav',
#  '001923-mixed.pt',
#  '002361-mixed.pt',
#  '002944-mixed.pt',
#  '002572-ref_emb.wav',
#  '001780-ref_emb.wav',
#  '003635-target.wav',
#  '002902-mixed.pt',
#  '003426-mixed.pt',
#  '001632-ref_emb.wav',
#  '004638-ref_emb.wav',
#  '002211-target.wav',
#  '001841-ref_emb.wav',
#  '002670-mixed.wav',
#  '003553-target.wav',
#  '004032-target.pt',
#  '000729-mixed.pt',
#  '005363-ref_emb.wav',
#  '003296-ref_emb.wav',
#  '002054-target.pt',
#  '000002-target.wav',
#  '005242-mixed.wav',
#  '003796-target.wav',
#  '004291-target.pt',
#  '001214-mixed.wav',
#  '001270-target.pt',
#  '001369-target.pt',
#  '005193-target.wav',
#  '004199-target.pt',
#  '001237-mixed.pt',
#  '003089-ref_emb.wav',
#  '003219-ref_emb.wav',
#  '004522-target.wav',
#  '001148-target.wav',
#  '003844-target.pt',
#  '001232-target.wav',
#  '005512-ref_emb.wav',
#  '004400-ref_emb.wav',
#  '002724-target.pt',
#  '002185-mixed.wav',
#  '001466-target.pt',
#  '002932-ref_emb.wav',
#  '003258-mixed.wav',
#  '003171-target.pt',
#  '001185-ref_emb.wav',
#  '001430-mixed.pt',
#  '002587-target.pt',
#  '002086-ref_emb.wav',
#  '003364-target.wav',
#  '002749-mixed.pt',
#  '002313-target.wav',
#  '002353-ref_emb.wav',
#  '000905-mixed.wav',
#  '003802-target.wav',
#  '003577-mixed.pt',
#  '001262-target.wav',
#  '000034-mixed.wav',
#  '002704-ref_emb.wav',
#  '003769-ref_emb.wav',
#  '003201-target.wav',
#  '002417-target.pt',
#  '001370-mixed.wav',
#  '003600-ref_emb.wav',
#  '004547-ref_emb.wav',
#  '003022-mixed.wav',
#  '001112-target.wav',
#  '005115-ref_emb.wav',
#  '000903-mixed.wav',
#  '004713-ref_emb.wav',
#  '002934-mixed.pt',
#  '002079-ref_emb.wav',
#  '004317-ref_emb.wav',
#  '004978-ref_emb.wav',
#  '000804-ref_emb.wav',
#  '003538-ref_emb.wav',
#  '000941-mixed.pt',
#  '003945-ref_emb.wav',
#  '003647-target.pt',
#  '001094-mixed.wav',
#  '000408-mixed.wav',
#  '000905-mixed.pt',
#  '005331-target.wav',
#  '001881-target.pt',
#  '001760-ref_emb.wav',
#  '003094-mixed.pt',
#  '002737-mixed.pt',
#  '004871-mixed.wav',
#  '004249-ref_emb.wav',
#  '005148-mixed.pt',
#  '005145-target.wav',
#  '001059-mixed.pt',
#  '001175-mixed.wav',
#  '003558-mixed.wav',
#  '000789-target.wav',
#  '001679-mixed.wav',
#  '000969-mixed.wav',
#  '003398-target.wav',
#  '005339-target.pt',
#  '000859-target.wav',
#  '004896-ref_emb.wav',
#  '004493-target.pt',
#  '003156-mixed.wav',
#  '002257-ref_emb.wav',
#  '004152-target.wav',
#  '004229-mixed.wav',
#  '003165-target.wav',
#  '005248-mixed.pt',
#  '002682-target.pt',
#  '000841-mixed.wav',
#  '000010-target.wav',
#  '004929-mixed.pt',
#  '000223-mixed.pt',
#  '001657-target.wav',
#  '000019-target.pt',
#  '003449-mixed.pt',
#  '001827-target.wav',
#  '003192-mixed.wav',
#  '000572-mixed.wav',
#  '003146-mixed.pt',
#  '001261-mixed.pt',
#  '002283-mixed.pt',
#  '003705-mixed.pt',
#  '001171-target.pt',
#  '000953-mixed.pt',
#  '002704-target.wav',
#  '000063-ref_emb.wav',
#  '004199-ref_emb.wav',
#  '003507-target.pt',
#  '003892-mixed.pt',
#  '003413-mixed.wav',
#  '003548-target.pt',
#  '002205-target.wav',
#  '002219-target.pt',
#  '001662-target.pt',
#  '005427-mixed.wav',
#  '001385-mixed.pt',
#  '003373-ref_emb.wav',
#  '000971-ref_emb.wav',
#  '002061-mixed.wav',
#  '001310-mixed.wav',
#  '004868-mixed.wav',
#  '004162-target.pt',
#  '002488-target.pt',
#  '002578-mixed.wav',
#  '004751-mixed.wav',
#  '004637-mixed.wav',
#  '005420-mixed.pt',
#  '005386-mixed.wav',
#  '001851-mixed.wav',
#  '004492-target.pt',
#  '004654-target.wav',
#  '005140-mixed.pt',
#  '000455-mixed.wav',
#  '005341-mixed.pt',
#  '001048-ref_emb.wav',
#  '000412-target.wav',
#  '002441-target.wav',
#  '002751-target.wav',
#  '002762-target.pt',
#  '001941-target.wav',
#  '005361-mixed.pt',
#  '004234-ref_emb.wav',
#  '000223-mixed.wav',
#  '002749-mixed.wav',
#  '002404-ref_emb.wav',
#  '003407-mixed.wav',
#  '002955-ref_emb.wav',
#  '000963-target.pt',
#  '004649-mixed.pt',
#  '000019-target.wav',
#  '004575-target.wav',
#  '002587-mixed.pt',
#  '003170-target.wav',
#  '001057-target.wav',
#  '002161-target.wav',
#  '004233-target.wav',
#  '002507-target.pt',
#  '002011-ref_emb.wav',
#  '001798-mixed.wav',
#  '004774-mixed.pt',
#  '002898-target.pt',
#  '001218-mixed.wav',
#  '000933-ref_emb.wav',
#  '000300-mixed.wav',
#  '000699-mixed.wav',
#  '002740-mixed.pt',
#  '001948-mixed.wav',
#  '003167-ref_emb.wav',
#  '002645-mixed.wav',
#  '005236-target.pt',
#  '002674-target.pt',
#  '002789-target.pt',
#  '004666-mixed.wav',
#  '005239-target.wav',
#  '002348-target.pt',
#  '000804-target.pt',
#  '005174-target.pt',
#  '000512-target.pt',
#  '005566-target.pt',
#  '005205-target.wav',
#  '000188-ref_emb.wav',
#  '004270-target.wav',
#  '005288-ref_emb.wav',
#  '004388-target.wav',
#  '003525-target.wav',
#  '002800-mixed.wav',
#  '000254-target.wav',
#  '003035-target.pt',
#  '001149-target.pt',
#  '005357-mixed.wav',
#  '000900-target.pt',
#  '002997-mixed.pt',
#  '001156-target.pt',
#  '004424-mixed.wav',
#  '002593-ref_emb.wav',
#  '004399-mixed.wav',
#  '004634-mixed.wav',
#  '002259-ref_emb.wav',
#  '000863-mixed.wav',
#  '002987-target.pt',
#  '001089-target.wav',
#  '002084-mixed.pt',
#  '005002-mixed.pt',
#  '004917-target.pt',
#  '002706-mixed.pt',
#  '002103-target.wav',
#  '002098-mixed.wav',
#  '004674-target.wav',
#  '004769-mixed.wav',
#  '000186-ref_emb.wav',
#  '002673-target.wav',
#  '002614-target.wav',
#  '003636-target.wav',
#  '000515-mixed.wav',
#  '003360-mixed.pt',
#  '003946-mixed.wav',
#  '003402-ref_emb.wav',
#  '005106-mixed.wav',
#  '001732-ref_emb.wav',
#  '001936-mixed.pt',
#  '001796-target.pt',
#  '001897-ref_emb.wav',
#  '001124-target.wav',
#  '004147-target.pt',
#  '003500-ref_emb.wav',
#  '001808-mixed.wav',
#  '002585-mixed.wav',
#  '002875-target.pt',
#  '005348-mixed.pt',
#  '002669-target.pt',
#  '005268-mixed.pt',
#  '001646-ref_emb.wav',
#  '001237-target.pt',
#  '000730-target.pt',
#  '002473-mixed.wav',
#  '002159-target.wav',
#  '000749-ref_emb.wav',
#  '004351-target.wav',
#  '003181-target.wav',
#  '005092-target.pt',
#  '003223-ref_emb.wav',
#  '001432-mixed.pt',
#  '000200-mixed.pt',
#  '000085-mixed.pt',
#  '005152-mixed.pt',
#  '001627-target.wav',
#  '001935-ref_emb.wav',
#  '004476-target.pt',
#  '004686-ref_emb.wav',
#  '002083-ref_emb.wav',
#  '000838-target.pt',
#  '002426-mixed.wav',
#  '004264-mixed.wav',
#  '001937-mixed.pt',
#  '002341-mixed.pt',
#  '004410-target.wav',
#  '004686-mixed.wav',
#  '004778-mixed.pt',
#  '005363-target.pt',
#  '002468-target.wav',
#  '005534-mixed.pt',
#  '004625-ref_emb.wav',
#  '004137-mixed.pt',
#  '000361-mixed.pt',
#  '002465-target.wav',
#  '000473-mixed.pt',
#  '000286-ref_emb.wav',
#  '001622-target.pt',
#  '003514-ref_emb.wav',
#  '000298-target.wav',
#  '003235-ref_emb.wav',
#  '000481-target.pt',
#  '002271-mixed.wav',
#  '002486-mixed.pt',
#  '002784-mixed.pt',
#  '000046-target.pt',
#  '003424-target.wav',
#  '002853-target.wav',
#  '000683-ref_emb.wav',
#  '002678-ref_emb.wav',
#  '004999-ref_emb.wav',
#  '000896-mixed.pt',
#  '001443-target.pt',
#  '000593-target.wav',
#  '001651-mixed.pt',
#  '000394-target.wav',
#  '000769-target.pt',
#  '003684-ref_emb.wav',
#  '001284-mixed.wav',
#  '005373-target.wav',
#  '003824-mixed.pt',
#  '000776-ref_emb.wav',
#  '003451-target.pt',
#  '003256-target.pt',
#  '003222-target.wav',
#  '003913-target.wav',
#  '000330-target.pt',
#  '003577-target.wav',
#  '005072-mixed.wav',
#  '004865-target.wav',
#  '002730-ref_emb.wav',
#  '002822-target.wav',
#  '000330-target.wav',
#  '000518-target.pt',
#  '002017-ref_emb.wav',
#  '000496-mixed.wav',
#  '000286-target.pt',
#  '000793-mixed.wav',
#  '001311-mixed.wav',
#  '000013-mixed.pt',
#  '000781-target.pt',
#  '000761-mixed.wav',
#  '004024-ref_emb.wav',
#  '004154-mixed.pt',
#  '003146-target.wav',
#  '000565-target.wav',
#  '002421-target.wav',
#  '000399-target.wav',
#  '001633-target.pt',
#  '000090-mixed.pt',
#  '000880-target.wav',
#  '004014-target.wav',
#  '002501-target.wav',
#  '003489-mixed.wav',
#  '003340-mixed.pt',
#  '004029-target.pt',
#  '005363-target.wav',
#  '003728-mixed.wav',
#  '003178-target.pt',
#  '000536-mixed.wav',
#  '005220-mixed.wav',
#  '001670-mixed.wav',
#  '002821-mixed.wav',
#  '002326-target.pt',
#  '001152-target.wav',
#  '000440-ref_emb.wav',
#  '000456-mixed.pt',
#  '001845-ref_emb.wav',
#  '005066-target.pt',
#  '003753-target.pt',
#  '000180-ref_emb.wav',
#  '005035-mixed.wav',
#  '000483-mixed.wav',
#  '002583-target.pt',
#  '002755-mixed.wav',
#  '002319-target.wav',
#  '002599-target.pt',
#  '004261-mixed.wav',
#  '005099-target.pt',
#  '004436-target.pt',
#  '000785-mixed.wav',
#  '001398-mixed.pt',
#  '002928-mixed.pt',
#  '001764-mixed.wav',
#  '002797-target.pt',
#  '003458-target.pt',
#  '003737-ref_emb.wav',
#  '000534-mixed.wav',
#  '000671-target.wav',
#  '004324-mixed.pt',
#  '000732-mixed.wav',
#  '001025-target.wav',
#  '000559-target.pt',
#  '000315-mixed.pt',
#  '005422-mixed.wav',
#  '000288-ref_emb.wav',
#  '005497-target.pt',
#  '003725-mixed.pt',
#  '000412-mixed.wav',
#  '005185-ref_emb.wav',
#  '004825-target.wav',
#  '000331-mixed.wav',
#  '005060-mixed.wav',
#  '004396-mixed.wav',
#  '002661-target.wav',
#  '000349-target.wav',
#  '003050-ref_emb.wav',
#  '003521-ref_emb.wav',
#  '004704-ref_emb.wav',
#  '000361-mixed.wav',
#  '004944-target.wav',
#  '005174-mixed.pt',
#  '002695-target.pt',
#  '002861-mixed.wav',
#  '003631-target.pt',
#  '005249-mixed.pt',
#  '004196-mixed.wav',
#  '002039-mixed.pt',
#  '003897-target.pt',
#  '001088-target.pt',
#  '000975-ref_emb.wav',
#  '002179-mixed.wav',
#  '002699-mixed.pt',
#  '005362-mixed.pt',
#  '002269-target.pt',
#  '004636-mixed.pt',
#  '001864-ref_emb.wav',
#  '004433-target.pt',
#  '000317-ref_emb.wav',
#  '002345-target.wav',
#  '004450-mixed.pt',
#  '002812-ref_emb.wav',
#  '003703-mixed.wav',
#  '004603-target.wav',
#  '002641-target.wav',
#  '001476-mixed.pt',
#  '000797-mixed.pt',
#  '000632-mixed.pt',
#  '003423-mixed.pt',
#  '005288-target.wav',
#  '004392-mixed.pt',
#  '000499-target.pt',
#  '005043-target.pt',
#  '000068-mixed.pt',
#  '000593-mixed.wav',
#  '001443-mixed.wav',
#  '001111-target.wav',
#  '005201-mixed.wav',
#  '000083-target.pt',
#  '001836-ref_emb.wav',
#  '000281-mixed.pt',
#  '000847-mixed.pt',
#  '000482-mixed.pt',
#  '001284-ref_emb.wav',
#  '003570-target.wav',
#  '001292-target.pt',
#  '005182-target.wav',
#  '002811-mixed.pt',
#  '004156-mixed.pt',
#  '004272-ref_emb.wav',
#  '004541-ref_emb.wav',
#  '003544-target.pt',
#  '003087-target.wav',
#  '004710-target.pt',
#  '001615-target.wav',
#  '001076-mixed.wav',
#  '004199-mixed.pt',
#  '004694-ref_emb.wav',
#  '002698-mixed.pt',
#  '003026-ref_emb.wav',
#  '002620-ref_emb.wav',
#  '005415-target.wav',
#  '003830-mixed.wav',
#  '000309-mixed.pt',
#  '004247-mixed.pt',
#  '002213-mixed.wav',
#  '000277-target.pt',
#  '005559-mixed.pt',
#  '000563-mixed.wav',
#  '002109-mixed.pt',
#  '002180-mixed.pt',
#  '002277-ref_emb.wav',
#  '003647-mixed.pt',
#  '004016-target.wav',
#  '000935-mixed.wav',
#  '001317-mixed.wav',
#  '003845-target.pt',
#  '001618-target.pt',
#  '000567-mixed.wav',
#  '000190-target.pt',
#  '004122-target.pt',
#  '002231-ref_emb.wav',
#  '004048-target.wav',
#  '002019-mixed.pt',
#  '000610-target.wav',
#  '005348-ref_emb.wav',
#  '001912-mixed.pt',
#  '000487-target.pt',
#  '002240-target.pt',
#  '001855-ref_emb.wav',
#  '005434-mixed.wav',
#  '001019-mixed.wav',
#  '001391-ref_emb.wav',
#  '000407-mixed.pt',
#  '001364-target.wav',
#  '004653-target.wav',
#  '002755-target.wav',
#  '004421-mixed.wav',
#  '002284-mixed.pt',
#  '004139-target.wav',
#  '002844-ref_emb.wav',
#  '000971-target.wav',
#  '000903-target.wav',
#  '004650-mixed.pt',
#  '000128-mixed.pt',
#  '002576-target.wav',
#  '000736-ref_emb.wav',
#  '001339-mixed.wav',
#  '001509-ref_emb.wav',
#  '000483-target.pt',
#  '005393-target.wav',
#  '003446-target.wav',
#  '001713-mixed.wav',
#  '005439-mixed.pt',
#  '002137-ref_emb.wav',
#  '005242-ref_emb.wav',
#  '003065-ref_emb.wav',
#  '000846-mixed.wav',
#  '000306-target.wav',
#  '003268-target.wav',
#  '000387-target.wav',
#  '004178-target.wav',
#  '002641-ref_emb.wav',
#  '004938-mixed.pt',
#  '001339-target.wav',
#  '001202-mixed.wav',
#  '005444-ref_emb.wav',
#  '003457-target.pt',
#  '004418-ref_emb.wav',
#  '000306-target.pt',
#  '000404-mixed.pt',
#  '005530-mixed.pt',
#  '000331-target.pt',
#  '002516-mixed.pt',
#  '004534-target.wav',
#  '005009-mixed.pt',
#  '001266-ref_emb.wav',
#  '002535-mixed.wav',
#  '004680-mixed.pt',
#  '002972-mixed.pt',
#  '005145-mixed.pt',
#  '002366-ref_emb.wav',
#  '002838-mixed.pt',
#  '004845-ref_emb.wav',
#  '005176-mixed.wav',
#  '003960-target.pt',
#  '003058-target.pt',
#  '005357-target.pt',
#  '002131-target.wav',
#  '003156-mixed.pt',
#  '002484-mixed.pt',
#  '000133-target.wav',
#  '001058-mixed.pt',
#  '000792-mixed.wav',
#  '002112-target.pt',
#  '000706-mixed.wav',
#  '003493-mixed.wav',
#  '000692-ref_emb.wav',
#  '004047-ref_emb.wav',
#  '004312-target.wav',
#  '004536-ref_emb.wav',
#  '005558-target.pt',
#  '004782-target.wav',
#  '005061-target.wav',
#  '000863-mixed.pt',
#  '001082-mixed.pt',
#  '000036-mixed.pt',
#  '005423-ref_emb.wav',
#  '005389-mixed.pt',
#  '005194-target.pt',
#  '001367-ref_emb.wav',
#  '004867-mixed.pt',
#  '003073-mixed.wav',
#  '000958-target.pt',
#  '005260-target.pt',
#  '002674-target.wav',
#  '000579-mixed.wav',
#  '002379-mixed.wav',
#  '000073-target.pt',
#  '000433-target.wav',
#  '001390-target.wav',
#  '000738-target.pt',
#  '002158-mixed.pt',
#  '001423-mixed.wav',
#  '004371-target.pt',
#  '002898-target.wav',
#  '001547-mixed.pt',
#  '000844-ref_emb.wav',
#  '001865-target.pt',
#  '002834-mixed.wav',
#  '001802-mixed.pt',
#  '000053-ref_emb.wav',
#  '004406-target.wav',
#  '002293-ref_emb.wav',
#  '003205-target.pt',
#  '005168-mixed.wav',
#  '000369-target.wav',
#  '005330-ref_emb.wav',
#  '004445-mixed.pt',
#  '001775-mixed.wav',
#  '001444-target.pt',
#  '004304-ref_emb.wav',
#  '004900-target.pt',
#  '004655-mixed.wav',
#  '004431-target.wav',
#  '005293-target.wav',
#  '001079-mixed.wav',
#  '003742-mixed.pt',
#  '003305-mixed.wav',
#  '002728-target.wav',
#  '004655-mixed.pt',
#  '003897-mixed.wav',
#  '000849-target.wav',
#  ...]

# %%
#Preprocess dataset
train_files = sorted(glob(os.path.join(TRAIN_DATA, glob_re_wav_emb)))
test_files = sorted(glob(os.path.join(TEST_DATA, glob_re_wav_emb)))

if len(train_files) == 0 or len(test_files):
    print("check train and test path files not in directory")
files  = train_files+test_files

for i in tqdm(range(len(files))):
    try:
        wave_file_path = files[i]
        wav_file_name = os.path.basename(wave_file_path)
        # Extract Embedding
        with open(wave_file_path, 'r') as f:
            LB_wave_file_path = f.readline().strip()
        emb_wav, _ = librosa.load(os.path.join('../',LB_wave_file_path), sr=16000)
        mel = torch.from_numpy(ap.get_mel(emb_wav)).cuda()
        #print(mel.shape)
        file_embedding = embedder(mel).cpu().detach().numpy()
    except:
        # if is not possible extract embedding because wav lenght is very small
        file_embedding = np.array([0]) # its make a error in training
        print("Embedding reference is very sort")
    output_name = wave_file_path.replace(glob_re_wav_emb.replace('*',''),'')+glob_re_emb.replace('*','')
    torch.save(torch.from_numpy(file_embedding.reshape(-1)), output_name)
# Out:
#   0%|          | 2/259819 [00:00<4:37:07, 15.63it/s]
# check train and test path files not in directory
#   2%|▏         | 4812/259819 [04:44<4:11:11, 16.92it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-30d436a33ab2> in <module>
#      16         mel = torch.from_numpy(ap.get_mel(emb_wav)).cuda()
#      17         #print(mel.shape)
# ---> 18         file_embedding = embedder(mel).cpu().detach().numpy()
#      19
#      20         # if is not possible extract embedding because wav lenght is very small
#
# ~/Edresson/anaconda3/envs/voicesplit/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# <ipython-input-5-4fd15c156305> in forward(self, mel)
#      28         mels = mel.unfold(1, self.window, self.stride) # (num_mels, T', window)
#      29         mels = mels.permute(1, 2, 0) # (T', window, num_mels)
# ---> 30         x, _ = self.lstm(mels) # (T', window, lstm_hidden)
#      31         x = x[:, -1, :] # (T', lstm_hidden), use last frame only
#      32         x = self.proj(x) # (T', emb_dim)
#
# ~/Edresson/anaconda3/envs/voicesplit/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/Edresson/anaconda3/envs/voicesplit/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     177         if batch_sizes is None:
#     178             result = _impl(input, hx, self._flat_weights, self.bias, self.num_layers,
# --> 179                            self.dropout, self.training, self.bidirectional, self.batch_first)
#     180         else:
#     181             result = _impl(input, batch_sizes, hx, self._flat_weights, self.bias,
#
# KeyboardInterrupt:

# %%
#file_embedding
# Out:
# array([-9.30385757e-03,  5.41789979e-02,  9.06330049e-02,  6.22695163e-02,
#         2.20813379e-02,  8.56699888e-04, -2.18634997e-02, -5.71655575e-03,
#         2.30765045e-02,  6.84375130e-03,  5.21903634e-02,  2.06298940e-02,
#        -1.68322830e-03,  2.84168012e-02, -4.99293301e-03, -2.33015195e-02,
#         2.07366832e-02, -4.94350716e-02,  6.57151267e-02,  3.51618789e-02,
#        -4.54175659e-02, -2.13632826e-02, -2.04372802e-03, -3.49387787e-02,
#        -5.92319779e-02,  5.97215481e-02,  3.63193341e-02, -1.33465361e-02,
#        -4.25689854e-03,  8.81210715e-03, -9.37813297e-02,  2.60864999e-02,
#        -7.97466747e-03, -2.80721323e-03, -6.61637560e-02, -6.85963454e-03,
#         1.76966004e-02, -2.56214738e-02, -9.70787834e-03, -4.84729782e-02,
#         7.53615517e-03,  1.79857463e-02, -1.18213892e-01, -4.07752581e-02,
#        -9.56033915e-02, -1.29147740e-02,  6.45934939e-02, -1.45624071e-01,
#        -6.98695146e-03, -6.02206700e-02,  3.54489870e-02, -4.85779420e-02,
#        -1.34030664e-02, -3.83446645e-03,  2.03137379e-02, -2.18939818e-02,
#        -2.87001254e-03, -6.49008574e-03,  3.06419618e-02,  4.26524095e-02,
#         2.26858109e-02,  3.85783496e-03, -4.49744873e-02,  4.33491990e-02,
#         7.08607808e-02,  1.40682990e-02, -1.59518328e-02,  7.00532924e-03,
#         8.78185034e-02, -1.91853512e-02,  4.80699688e-02, -7.90541805e-03,
#        -4.09820043e-02, -5.60661033e-03, -7.31679723e-02, -3.71791311e-02,
#         6.51042014e-02, -9.86738130e-03,  5.26152439e-02, -5.13619445e-02,
#        -5.27251922e-02,  6.85087591e-02, -6.79370016e-02,  1.33215752e-03,
#         2.42487597e-03,  4.61497009e-02,  1.29347686e-02,  3.71128395e-02,
#        -6.96740001e-02, -8.14210158e-03, -1.27947598e-03,  1.50019694e-02,
#        -4.22077551e-02,  4.63677570e-03,  6.51928782e-02, -1.12321815e-02,
#         5.76262884e-02,  7.88713098e-02, -4.20339778e-02, -1.57998074e-02,
#         2.65683290e-02, -3.51153761e-02, -3.97829805e-03, -1.43093988e-02,
#         2.49817856e-02,  4.20699269e-02, -2.12458931e-02,  4.23465930e-02,
#         4.97404560e-02,  5.86535186e-02,  2.99318205e-03, -4.75075878e-02,
#         3.55671011e-02,  1.02465153e-02,  3.95308211e-02,  3.41502167e-02,
#         3.08922920e-02,  2.68952176e-02,  1.06625324e-02,  1.14527429e-02,
#        -5.13622798e-02, -1.49528468e-02,  9.24527273e-02, -6.75329044e-02,
#         2.09581829e-03,  2.64860187e-02, -7.98440650e-02,  2.34777406e-02,
#         7.32370615e-02,  9.44046080e-02, -1.47173703e-02,  1.85838677e-02,
#         5.33283465e-02, -7.91154280e-02,  1.34588806e-02,  8.25420674e-03,
#         4.66717407e-03, -3.01195681e-02, -7.82165229e-02, -5.36293760e-02,
#         3.07960622e-02,  3.83024253e-02, -4.60379310e-02, -2.87927333e-02,
#         3.14989313e-03, -4.34478708e-02, -4.97377366e-02,  3.85586545e-02,
#        -8.13278183e-03, -5.74793816e-02,  5.91671914e-02, -1.59628987e-02,
#         6.34388183e-04,  8.51889141e-03, -9.84347165e-02, -2.14327537e-02,
#        -4.59324755e-03,  2.30600033e-02,  5.33378460e-02,  2.30803974e-02,
#         3.43944021e-02, -7.34029338e-02, -4.00856324e-02,  1.01627987e-02,
#        -4.77306060e-02, -2.01096069e-02,  5.41028231e-02, -4.65270951e-02,
#        -9.72870737e-02, -4.13014889e-02,  5.66016510e-03, -5.23891971e-02,
#        -5.05143888e-02,  1.18636943e-01, -5.63097522e-02, -4.31293389e-03,
#        -1.67284198e-02, -1.73168629e-02,  7.11916313e-02, -3.66023295e-02,
#         3.21828462e-02, -7.83990175e-02, -2.68945601e-02,  9.47201774e-02,
#         4.07145470e-02,  6.61355332e-02,  1.12636657e-02, -4.40072455e-02,
#         4.77660000e-02,  6.50962219e-02, -7.04237372e-02,  3.37257423e-02,
#         1.85549278e-02, -6.18660997e-05, -5.09684458e-02,  6.12459667e-02,
#        -6.20100312e-02, -6.76986873e-02,  8.86803642e-02,  2.78647952e-02,
#         2.09685811e-03, -9.32255201e-03,  6.85087442e-02,  4.24879901e-02,
#        -1.59106497e-02,  3.51847708e-02,  3.93377356e-02,  1.05815902e-02,
#         7.73462877e-02,  4.63163108e-02, -5.95834590e-02, -3.10144331e-02,
#         4.82415641e-03, -5.10910116e-02,  1.85846537e-02, -8.12100917e-02,
#        -5.94046265e-02, -4.29220460e-02,  6.09992538e-04,  8.68032947e-02,
#        -7.26278871e-02,  1.29168611e-02,  7.18561634e-02,  8.86406824e-02,
#        -3.81214358e-03, -1.87205744e-03,  5.24003617e-02,  9.81422961e-02,
#         1.45270461e-02,  7.00556040e-02, -1.54568376e-02,  1.15654040e-02,
#         2.72154454e-02,  7.59893805e-02,  5.24530327e-03, -6.12813979e-02,
#         1.68235544e-02, -1.57231782e-02,  4.90667159e-03,  5.85586838e-02,
#        -3.15532945e-02, -6.79342728e-03,  1.72584914e-02,  2.15932205e-02,
#         7.03769783e-03, -1.35677890e-03,  1.16337985e-02,  1.63864717e-02,
#         3.70930023e-02, -4.79750074e-02,  5.89660443e-02, -1.18050501e-01,
#        -1.03304116e-02, -6.21167012e-03, -9.00404304e-02, -9.82917752e-03],
#       dtype=float32)
